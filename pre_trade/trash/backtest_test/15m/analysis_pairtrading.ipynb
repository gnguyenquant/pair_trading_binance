# %%
import pandas as pd

# %%
backtest_path='../../data/backtest/training/'
backtest_results_df=pd.read_csv('{}backtest_results.csv'.format(backtest_path))

# %%
#backtest_results_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#print(backtest_results_df)

# %%
DOT_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='DOTUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
ETH_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ETHUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
ADA_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ADAUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
AVAX_NEAR_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='AVAXUSDT') &(backtest_results_df['compare_symbol']=='NEARUSDT')]
ALGO_ATOM_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ALGOUSDT') &(backtest_results_df['compare_symbol']=='ATOMUSDT')]
ETH_ADA_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ETHUSDT') &(backtest_results_df['compare_symbol']=='ADAUSDT')]

# %%
DOT_ALGO_1h_backtest_df=DOT_ALGO_backtest_df.loc[DOT_ALGO_backtest_df['timeframe']=='1h']
DOT_ALGO_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
DOT_ALGO_1h_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/2940955369.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DOT_ALGO_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 14       DOTUSDT       ALGOUSDT        1h          3         0.0         4
# 5        DOTUSDT       ALGOUSDT        1h          2         0.0         3
# 13       DOTUSDT       ALGOUSDT        1h          3         0.0         4
# 17       DOTUSDT       ALGOUSDT        1h          3         0.0         4
# 15       DOTUSDT       ALGOUSDT        1h          3         0.0         4
# 4        DOTUSDT       ALGOUSDT        1h          2         0.0         3
# 28       DOTUSDT       ALGOUSDT        1h          4         0.0         5
# ...

# %%
DOT_ALGO_1h_backtest_df.tail(10)
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 0        DOTUSDT       ALGOUSDT        1h          2         0.0         3
# 31       DOTUSDT       ALGOUSDT        1h          4         0.5         5
# 20       DOTUSDT       ALGOUSDT        1h          3         0.5         4
# 12       DOTUSDT       ALGOUSDT        1h          3         0.0         4
# 18       DOTUSDT       ALGOUSDT        1h          3         0.5         4
# 30       DOTUSDT       ALGOUSDT        1h          4         0.5         5
# 7        DOTUSDT       ALGOUSDT        1h          2         0.5         3
# 24       DOTUSDT       ALGOUSDT        1h          4         0.0         5
# 1        DOTUSDT       ALGOUSDT        1h          2         0.0         3
# 8        DOTUSDT       ALGOUSDT        1h          2         0.5         3
#
#     period  PnL_final
# 0       15    -321.70
# 31      20    -322.25
# 20      25    -340.32
# 12      15    -345.56
# 18      15    -375.21
# ...

# %%
DOT_ALGO_2h_backtest_df=DOT_ALGO_backtest_df.loc[DOT_ALGO_backtest_df['timeframe']=='2h']
DOT_ALGO_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
DOT_ALGO_2h_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/2700262957.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DOT_ALGO_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 58       DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 53       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 57       DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 51       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 52       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 59       DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 62       DOTUSDT       ALGOUSDT        2h          4         0.0         5
# ...

# %%
DOT_ALGO_2h_backtest_df.tail(10)
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 67       DOTUSDT       ALGOUSDT        2h          4         0.5         5
# 66       DOTUSDT       ALGOUSDT        2h          4         0.5         5
# 60       DOTUSDT       ALGOUSDT        2h          4         0.0         5
# 45       DOTUSDT       ALGOUSDT        2h          2         0.5         3
# 39       DOTUSDT       ALGOUSDT        2h          2         0.0         3
# 48       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 40       DOTUSDT       ALGOUSDT        2h          2         0.0         3
# 49       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 44       DOTUSDT       ALGOUSDT        2h          2         0.5         3
# 55       DOTUSDT       ALGOUSDT        2h          3         0.5         4
#
#     period  PnL_final
# 67      20      18.40
# 66      15     -16.77
# 60      15     -35.28
# 45      30     -39.18
# 39      30     -43.64
# ...

# %%
DOT_ALGO_1d_backtest_df=DOT_ALGO_backtest_df.loc[DOT_ALGO_backtest_df['timeframe']=='1d']
DOT_ALGO_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
DOT_ALGO_1d_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/469523510.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DOT_ALGO_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 86       DOTUSDT       ALGOUSDT        1d          3         0.0         4
# 87       DOTUSDT       ALGOUSDT        1d          3         0.0         4
# 92       DOTUSDT       ALGOUSDT        1d          3         0.5         4
# 93       DOTUSDT       ALGOUSDT        1d          3         0.5         4
# 94       DOTUSDT       ALGOUSDT        1d          3         0.5         4
# 88       DOTUSDT       ALGOUSDT        1d          3         0.0         4
# 90       DOTUSDT       ALGOUSDT        1d          3         0.5         4
# ...

# %%
DOT_ALGO_1d_backtest_df.tail(10)
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 106       DOTUSDT       ALGOUSDT        1d          4         0.5         5
# 100       DOTUSDT       ALGOUSDT        1d          4         0.0         5
# 81        DOTUSDT       ALGOUSDT        1d          2         0.5         3
# 79        DOTUSDT       ALGOUSDT        1d          2         0.5         3
# 76        DOTUSDT       ALGOUSDT        1d          2         0.0         3
# 80        DOTUSDT       ALGOUSDT        1d          2         0.5         3
# 75        DOTUSDT       ALGOUSDT        1d          2         0.0         3
# 74        DOTUSDT       ALGOUSDT        1d          2         0.0         3
# 78        DOTUSDT       ALGOUSDT        1d          2         0.5         3
# 72        DOTUSDT       ALGOUSDT        1d          2         0.0         3
#
#      period  PnL_final
# 106      35    -190.59
# 100      35    -190.59
# 81       30    -251.26
# 79       20    -431.12
# ...

# %%
ETH_ALGO_1h_backtest_df=ETH_ALGO_backtest_df.loc[ETH_ALGO_backtest_df['timeframe']=='1h']
ETH_ALGO_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
ETH_ALGO_1h_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/2248652680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ETH_ALGO_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 127       ETHUSDT       ALGOUSDT        1h          3         0.5         4
# 108       ETHUSDT       ALGOUSDT        1h          2         0.0         3
# 117       ETHUSDT       ALGOUSDT        1h          2         0.5         3
# 114       ETHUSDT       ALGOUSDT        1h          2         0.5         3
# 135       ETHUSDT       ALGOUSDT        1h          4         0.0         5
# 122       ETHUSDT       ALGOUSDT        1h          3         0.0         4
# 115       ETHUSDT       ALGOUSDT        1h          2         0.5         3
# ...

# %%
ETH_ALGO_1h_backtest_df.tail(10)
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 126       ETHUSDT       ALGOUSDT        1h          3         0.5         4
# 124       ETHUSDT       ALGOUSDT        1h          3         0.0         4
# 119       ETHUSDT       ALGOUSDT        1h          2         0.5         3
# 137       ETHUSDT       ALGOUSDT        1h          4         0.0         5
# 112       ETHUSDT       ALGOUSDT        1h          2         0.0         3
# 130       ETHUSDT       ALGOUSDT        1h          3         0.5         4
# 139       ETHUSDT       ALGOUSDT        1h          4         0.5         5
# 138       ETHUSDT       ALGOUSDT        1h          4         0.5         5
# 113       ETHUSDT       ALGOUSDT        1h          2         0.0         3
# 132       ETHUSDT       ALGOUSDT        1h          4         0.0         5
#
#      period  PnL_final
# 126      15    -449.21
# 124      35    -451.35
# 119      40    -464.96
# 137      40    -474.17
# ...

# %%
ETH_ALGO_2h_backtest_df=ETH_ALGO_backtest_df.loc[ETH_ALGO_backtest_df['timeframe']=='2h']
ETH_ALGO_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
ETH_ALGO_2h_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/1853745195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ETH_ALGO_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 494       ETHUSDT       ALGOUSDT        2h          4         0.0         5
# 496       ETHUSDT       ALGOUSDT        2h          4         0.0         5
# 474       ETHUSDT       ALGOUSDT        2h          2         0.5         3
# 502       ETHUSDT       ALGOUSDT        2h          4         0.5         5
# 499       ETHUSDT       ALGOUSDT        2h          4         0.5         5
# 493       ETHUSDT       ALGOUSDT        2h          4         0.0         5
# 497       ETHUSDT       ALGOUSDT        2h          4         0.0         5
# ...

# %%
ETH_ALGO_1d_backtest_df=ETH_ALGO_backtest_df.loc[ETH_ALGO_backtest_df['timeframe']=='1d']
ETH_ALGO_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
ETH_ALGO_1d_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/352191571.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ETH_ALGO_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 413       ETHUSDT       ALGOUSDT        1d          3         0.0         4
# 419       ETHUSDT       ALGOUSDT        1d          3         0.5         4
# 412       ETHUSDT       ALGOUSDT        1d          3         0.0         4
# 424       ETHUSDT       ALGOUSDT        1d          4         0.0         5
# 423       ETHUSDT       ALGOUSDT        1d          4         0.0         5
# 418       ETHUSDT       ALGOUSDT        1d          3         0.5         4
# 429       ETHUSDT       ALGOUSDT        1d          4         0.5         5
# ...

# %%
ETH_ALGO_1d_backtest_df.tail(10)
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 408       ETHUSDT       ALGOUSDT        1d          3         0.0         4
# 406       ETHUSDT       ALGOUSDT        1d          2         0.5         3
# 401       ETHUSDT       ALGOUSDT        1d          2         0.0         3
# 407       ETHUSDT       ALGOUSDT        1d          2         0.5         3
# 398       ETHUSDT       ALGOUSDT        1d          2         0.0         3
# 397       ETHUSDT       ALGOUSDT        1d          2         0.0         3
# 405       ETHUSDT       ALGOUSDT        1d          2         0.5         3
# 404       ETHUSDT       ALGOUSDT        1d          2         0.5         3
# 402       ETHUSDT       ALGOUSDT        1d          2         0.5         3
# 396       ETHUSDT       ALGOUSDT        1d          2         0.0         3
#
#      period  PnL_final
# 408      15    -220.56
# 406      35    -292.36
# 401      40    -296.91
# 407      40    -314.44
# ...

# %%
ADA_ALGO_1h_backtest_df=ADA_ALGO_backtest_df.loc[ADA_ALGO_backtest_df['timeframe']=='1h']
ADA_ALGO_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
ADA_ALGO_1h_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/1410303546.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ADA_ALGO_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 241       ADAUSDT       ALGOUSDT        1h          4         0.0         5
# 222       ADAUSDT       ALGOUSDT        1h          2         0.5         3
# 247       ADAUSDT       ALGOUSDT        1h          4         0.5         5
# 242       ADAUSDT       ALGOUSDT        1h          4         0.0         5
# 246       ADAUSDT       ALGOUSDT        1h          4         0.5         5
# 245       ADAUSDT       ALGOUSDT        1h          4         0.0         5
# 229       ADAUSDT       ALGOUSDT        1h          3         0.0         4
# ...

# %%
ADA_ALGO_1h_backtest_df.tail(10)
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 237       ADAUSDT       ALGOUSDT        1h          3         0.5         4
# 249       ADAUSDT       ALGOUSDT        1h          4         0.5         5
# 218       ADAUSDT       ALGOUSDT        1h          2         0.0         3
# 226       ADAUSDT       ALGOUSDT        1h          2         0.5         3
# 227       ADAUSDT       ALGOUSDT        1h          2         0.5         3
# 221       ADAUSDT       ALGOUSDT        1h          2         0.0         3
# 238       ADAUSDT       ALGOUSDT        1h          3         0.5         4
# 233       ADAUSDT       ALGOUSDT        1h          3         0.0         4
# 239       ADAUSDT       ALGOUSDT        1h          3         0.5         4
# 230       ADAUSDT       ALGOUSDT        1h          3         0.0         4
#
#      period  PnL_final
# 237      30    -584.12
# 249      30    -589.85
# 218      25    -597.53
# 226      35    -609.84
# ...

# %%
ADA_ALGO_2h_backtest_df=ADA_ALGO_backtest_df.loc[ADA_ALGO_backtest_df['timeframe']=='2h']
ADA_ALGO_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
ADA_ALGO_2h_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/2359734169.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ADA_ALGO_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 276       ADAUSDT       ALGOUSDT        2h          4         0.0         5
# 280       ADAUSDT       ALGOUSDT        2h          4         0.0         5
# 263       ADAUSDT       ALGOUSDT        2h          2         0.5         3
# 286       ADAUSDT       ALGOUSDT        2h          4         0.5         5
# 279       ADAUSDT       ALGOUSDT        2h          4         0.0         5
# 277       ADAUSDT       ALGOUSDT        2h          4         0.0         5
# 278       ADAUSDT       ALGOUSDT        2h          4         0.0         5
# ...

# %%
ADA_ALGO_1d_backtest_df=ADA_ALGO_backtest_df.loc[ADA_ALGO_backtest_df['timeframe']=='1d']
ADA_ALGO_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
ADA_ALGO_1d_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/515204267.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ADA_ALGO_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 195       ADAUSDT       ALGOUSDT        1d          3         0.0         4
# 203       ADAUSDT       ALGOUSDT        1d          3         0.5         4
# 202       ADAUSDT       ALGOUSDT        1d          3         0.5         4
# 201       ADAUSDT       ALGOUSDT        1d          3         0.5         4
# 197       ADAUSDT       ALGOUSDT        1d          3         0.0         4
# 196       ADAUSDT       ALGOUSDT        1d          3         0.0         4
# 205       ADAUSDT       ALGOUSDT        1d          4         0.0         5
# ...

# %%
ADA_ALGO_1d_backtest_df.tail(10)
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 190       ADAUSDT       ALGOUSDT        1d          2         0.5         3
# 184       ADAUSDT       ALGOUSDT        1d          2         0.0         3
# 189       ADAUSDT       ALGOUSDT        1d          2         0.5         3
# 188       ADAUSDT       ALGOUSDT        1d          2         0.5         3
# 187       ADAUSDT       ALGOUSDT        1d          2         0.5         3
# 198       ADAUSDT       ALGOUSDT        1d          3         0.5         4
# 181       ADAUSDT       ALGOUSDT        1d          2         0.0         3
# 192       ADAUSDT       ALGOUSDT        1d          3         0.0         4
# 186       ADAUSDT       ALGOUSDT        1d          2         0.5         3
# 180       ADAUSDT       ALGOUSDT        1d          2         0.0         3
#
#      period  PnL_final
# 190      35    -309.99
# 184      35    -391.88
# 189      30    -429.58
# 188      25    -528.09
# ...

# %%
AVAX_NEAR_1h_backtest_df=AVAX_NEAR_backtest_df.loc[AVAX_NEAR_backtest_df['timeframe']=='1h']
AVAX_NEAR_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
AVAX_NEAR_1h_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/1092648475.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AVAX_NEAR_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 329      AVAXUSDT       NEARUSDT        1h          2         0.0         3
# 328      AVAXUSDT       NEARUSDT        1h          2         0.0         3
# 353      AVAXUSDT       NEARUSDT        1h          4         0.0         5
# 352      AVAXUSDT       NEARUSDT        1h          4         0.0         5
# 359      AVAXUSDT       NEARUSDT        1h          4         0.5         5
# 327      AVAXUSDT       NEARUSDT        1h          2         0.0         3
# 358      AVAXUSDT       NEARUSDT        1h          4         0.5         5
# ...

# %%
(AVAX_NEAR_1h_backtest_df.tail(10))
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 333      AVAXUSDT       NEARUSDT        1h          2         0.5         3
# 331      AVAXUSDT       NEARUSDT        1h          2         0.5         3
# 342      AVAXUSDT       NEARUSDT        1h          3         0.5         4
# 332      AVAXUSDT       NEARUSDT        1h          2         0.5         3
# 345      AVAXUSDT       NEARUSDT        1h          3         0.5         4
# 324      AVAXUSDT       NEARUSDT        1h          2         0.0         3
# 337      AVAXUSDT       NEARUSDT        1h          3         0.0         4
# 344      AVAXUSDT       NEARUSDT        1h          3         0.5         4
# 330      AVAXUSDT       NEARUSDT        1h          2         0.5         3
# 343      AVAXUSDT       NEARUSDT        1h          3         0.5         4
#
#      period  PnL_final
# 333      30    -522.81
# 331      20    -527.80
# 342      15    -576.08
# 332      25    -589.52
# ...

# %%
AVAX_NEAR_2h_backtest_df=AVAX_NEAR_backtest_df.loc[AVAX_NEAR_backtest_df['timeframe']=='2h']
AVAX_NEAR_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
(AVAX_NEAR_2h_backtest_df.head(10))
# Out:
# /tmp/ipykernel_145357/4117642658.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AVAX_NEAR_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 148      AVAXUSDT       NEARUSDT        2h          2         0.0         3
# 154      AVAXUSDT       NEARUSDT        2h          2         0.5         3
# 155      AVAXUSDT       NEARUSDT        2h          2         0.5         3
# 147      AVAXUSDT       NEARUSDT        2h          2         0.0         3
# 166      AVAXUSDT       NEARUSDT        2h          3         0.5         4
# 146      AVAXUSDT       NEARUSDT        2h          2         0.0         3
# 153      AVAXUSDT       NEARUSDT        2h          2         0.5         3
# ...

# %%
(AVAX_NEAR_2h_backtest_df.tail(10))
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 178      AVAXUSDT       NEARUSDT        2h          4         0.5         5
# 177      AVAXUSDT       NEARUSDT        2h          4         0.5         5
# 144      AVAXUSDT       NEARUSDT        2h          2         0.0         3
# 174      AVAXUSDT       NEARUSDT        2h          4         0.5         5
# 163      AVAXUSDT       NEARUSDT        2h          3         0.5         4
# 156      AVAXUSDT       NEARUSDT        2h          3         0.0         4
# 151      AVAXUSDT       NEARUSDT        2h          2         0.5         3
# 170      AVAXUSDT       NEARUSDT        2h          4         0.0         5
# 150      AVAXUSDT       NEARUSDT        2h          2         0.5         3
# 162      AVAXUSDT       NEARUSDT        2h          3         0.5         4
#
#      period  PnL_final
# 178      35    -247.93
# 177      30    -284.52
# 144      15    -374.66
# 174      15    -388.42
# ...

# %%
AVAX_NEAR_1d_backtest_df=AVAX_NEAR_backtest_df.loc[AVAX_NEAR_backtest_df['timeframe']=='1d']
AVAX_NEAR_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
(AVAX_NEAR_1d_backtest_df.head(10))
# Out:
# /tmp/ipykernel_145357/3341669124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AVAX_NEAR_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 305      AVAXUSDT       NEARUSDT        1d          3         0.0         4
# 304      AVAXUSDT       NEARUSDT        1d          3         0.0         4
# 311      AVAXUSDT       NEARUSDT        1d          3         0.5         4
# 296      AVAXUSDT       NEARUSDT        1d          2         0.5         3
# 310      AVAXUSDT       NEARUSDT        1d          3         0.5         4
# 316      AVAXUSDT       NEARUSDT        1d          4         0.0         5
# 315      AVAXUSDT       NEARUSDT        1d          4         0.0         5
# ...

# %%
(AVAX_NEAR_1d_backtest_df.tail(10))
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 300      AVAXUSDT       NEARUSDT        1d          3         0.0         4
# 295      AVAXUSDT       NEARUSDT        1d          2         0.5         3
# 289      AVAXUSDT       NEARUSDT        1d          2         0.0         3
# 291      AVAXUSDT       NEARUSDT        1d          2         0.0         3
# 301      AVAXUSDT       NEARUSDT        1d          3         0.0         4
# 302      AVAXUSDT       NEARUSDT        1d          3         0.0         4
# 298      AVAXUSDT       NEARUSDT        1d          2         0.5         3
# 299      AVAXUSDT       NEARUSDT        1d          2         0.5         3
# 293      AVAXUSDT       NEARUSDT        1d          2         0.0         3
# 292      AVAXUSDT       NEARUSDT        1d          2         0.0         3
#
#      period  PnL_final
# 300      15    -647.81
# 295      20    -651.19
# 289      20   -1621.55
# 291      30   -2736.80
# ...

# %%
ALGO_ATOM_1h_backtest_df=ALGO_ATOM_backtest_df.loc[ALGO_ATOM_backtest_df['timeframe']=='1h']
ALGO_ATOM_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
(ALGO_ATOM_1h_backtest_df.head(10))
# Out:
# /tmp/ipykernel_145357/2117090004.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ALGO_ATOM_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 438      ALGOUSDT       ATOMUSDT        1h          2         0.5         3
# 447      ALGOUSDT       ATOMUSDT        1h          3         0.0         4
# 441      ALGOUSDT       ATOMUSDT        1h          2         0.5         3
# 448      ALGOUSDT       ATOMUSDT        1h          3         0.0         4
# 435      ALGOUSDT       ATOMUSDT        1h          2         0.0         3
# 450      ALGOUSDT       ATOMUSDT        1h          3         0.5         4
# 453      ALGOUSDT       ATOMUSDT        1h          3         0.5         4
# ...

# %%
ALGO_ATOM_1h_backtest_df.tail(10)
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 467      ALGOUSDT       ATOMUSDT        1h          4         0.5         5
# 433      ALGOUSDT       ATOMUSDT        1h          2         0.0         3
# 458      ALGOUSDT       ATOMUSDT        1h          4         0.0         5
# 437      ALGOUSDT       ATOMUSDT        1h          2         0.0         3
# 462      ALGOUSDT       ATOMUSDT        1h          4         0.5         5
# 464      ALGOUSDT       ATOMUSDT        1h          4         0.5         5
# 465      ALGOUSDT       ATOMUSDT        1h          4         0.5         5
# 457      ALGOUSDT       ATOMUSDT        1h          4         0.0         5
# 463      ALGOUSDT       ATOMUSDT        1h          4         0.5         5
# 456      ALGOUSDT       ATOMUSDT        1h          4         0.0         5
#
#      period  PnL_final
# 467      40    -138.28
# 433      20    -166.53
# 458      25    -244.80
# 437      40    -254.87
# ...

# %%
ALGO_ATOM_2h_backtest_df=ALGO_ATOM_backtest_df.loc[ALGO_ATOM_backtest_df['timeframe']=='2h']
ALGO_ATOM_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
ALGO_ATOM_2h_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/562027606.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ALGO_ATOM_2h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 388      ALGOUSDT       ATOMUSDT        2h          4         0.0         5
# 377      ALGOUSDT       ATOMUSDT        2h          3         0.0         4
# 387      ALGOUSDT       ATOMUSDT        2h          4         0.0         5
# 389      ALGOUSDT       ATOMUSDT        2h          4         0.0         5
# 394      ALGOUSDT       ATOMUSDT        2h          4         0.5         5
# 383      ALGOUSDT       ATOMUSDT        2h          3         0.5         4
# 363      ALGOUSDT       ATOMUSDT        2h          2         0.0         3
# ...

# %%
ALGO_ATOM_2h_backtest_df.tail(10)
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 381      ALGOUSDT       ATOMUSDT        2h          3         0.5         4
# 373      ALGOUSDT       ATOMUSDT        2h          3         0.0         4
# 380      ALGOUSDT       ATOMUSDT        2h          3         0.5         4
# 379      ALGOUSDT       ATOMUSDT        2h          3         0.5         4
# 372      ALGOUSDT       ATOMUSDT        2h          3         0.0         4
# 384      ALGOUSDT       ATOMUSDT        2h          4         0.0         5
# 367      ALGOUSDT       ATOMUSDT        2h          2         0.5         3
# 390      ALGOUSDT       ATOMUSDT        2h          4         0.5         5
# 378      ALGOUSDT       ATOMUSDT        2h          3         0.5         4
# 368      ALGOUSDT       ATOMUSDT        2h          2         0.5         3
#
#      period  PnL_final
# 381      30    -239.50
# 373      20    -240.73
# 380      25    -294.32
# 379      20    -342.54
# ...

# %%
ALGO_ATOM_1d_backtest_df=ALGO_ATOM_backtest_df.loc[ALGO_ATOM_backtest_df['timeframe']=='1d']
ALGO_ATOM_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
ALGO_ATOM_1d_backtest_df.head(10)
# Out:
# /tmp/ipykernel_145357/3371818619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ALGO_ATOM_1d_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 627      ALGOUSDT       ATOMUSDT        1d          3         0.0         4
# 633      ALGOUSDT       ATOMUSDT        1d          3         0.5         4
# 620      ALGOUSDT       ATOMUSDT        1d          2         0.5         3
# 624      ALGOUSDT       ATOMUSDT        1d          3         0.0         4
# 614      ALGOUSDT       ATOMUSDT        1d          2         0.0         3
# 629      ALGOUSDT       ATOMUSDT        1d          3         0.0         4
# 635      ALGOUSDT       ATOMUSDT        1d          3         0.5         4
# ...

# %%
ALGO_ATOM_1d_backtest_df.tail(10)
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 643      ALGOUSDT       ATOMUSDT        1d          4         0.5         5
# 623      ALGOUSDT       ATOMUSDT        1d          2         0.5         3
# 632      ALGOUSDT       ATOMUSDT        1d          3         0.5         4
# 622      ALGOUSDT       ATOMUSDT        1d          2         0.5         3
# 619      ALGOUSDT       ATOMUSDT        1d          2         0.5         3
# 616      ALGOUSDT       ATOMUSDT        1d          2         0.0         3
# 615      ALGOUSDT       ATOMUSDT        1d          2         0.0         3
# 617      ALGOUSDT       ATOMUSDT        1d          2         0.0         3
# 618      ALGOUSDT       ATOMUSDT        1d          2         0.5         3
# 612      ALGOUSDT       ATOMUSDT        1d          2         0.0         3
#
#      period  PnL_final
# 643      20    -321.90
# 623      40    -388.52
# 632      25    -406.13
# 622      35    -471.07
# ...

# %%
ETH_ADA_1h_backtest_df=ETH_ADA_backtest_df.loc[ETH_ADA_backtest_df['timeframe']=='1h']
ETH_ADA_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
ETH_ADA_1h_backtest_df.head(10)
ETH_ADA_backtest_df
# Out:
# /tmp/ipykernel_145357/2967674983.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ETH_ADA_1h_backtest_df.sort_values(by='PnL_final',inplace=True,ascending=False)
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 576       ETHUSDT        ADAUSDT        2h          2         0.0         3
# 577       ETHUSDT        ADAUSDT        2h          2         0.0         3
# 578       ETHUSDT        ADAUSDT        2h          2         0.0         3
# 579       ETHUSDT        ADAUSDT        2h          2         0.0         3
# 580       ETHUSDT        ADAUSDT        2h          2         0.0         3
# 581       ETHUSDT        ADAUSDT        2h          2         0.0         3
# 582       ETHUSDT        ADAUSDT        2h          2         0.5         3
# ...
