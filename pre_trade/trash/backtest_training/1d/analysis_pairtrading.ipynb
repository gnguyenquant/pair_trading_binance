# %%
import pandas as pd

# %%
backtest_path='../../../data/backtest/training/'
backtest_results_df=pd.read_csv('{}backtest_training_1d.csv'.format(backtest_path))

# %%
backtest_results_df.sort_values(by='PnL_final',inplace=True,ascending=False)
backtest_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 87      AVAXUSDT       NEARUSDT        1d          3         0.0         4
# 41       ADAUSDT       ALGOUSDT        1d          2         0.0         3
# 93      AVAXUSDT       NEARUSDT        1d          3         0.5         4
# 50       ADAUSDT       ALGOUSDT        1d          3         0.0         4
# 4        DOTUSDT       ALGOUSDT        1d          2         0.0         3
# ..           ...            ...       ...        ...         ...       ...
# 85      AVAXUSDT       NEARUSDT        1d          3         0.0         4
# 81      AVAXUSDT       NEARUSDT        1d          2         0.5         3
# 75      AVAXUSDT       NEARUSDT        1d          2         0.0         3
# 82      AVAXUSDT       NEARUSDT        1d          2         0.5         3
# 76      AVAXUSDT       NEARUSDT        1d          2         0.0         3
#
#     period  PnL_final
# 87      40    3112.04
# ...

# %%
DOT_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='DOTUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
ADA_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ADAUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
AVAX_NEAR_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='AVAXUSDT') &(backtest_results_df['compare_symbol']=='NEARUSDT')]
ETH_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ETHUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
ETH_BNB_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ETHUSDT') &(backtest_results_df['compare_symbol']=='BNBUSDT')]
ALGO_ATOM_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ALGOUSDT') &(backtest_results_df['compare_symbol']=='ATOMUSDT')]
ETH_ADA_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ETHUSDT') &(backtest_results_df['compare_symbol']=='ADAUSDT')]
BNB_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='BNBUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
ETH_ATOM_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ETHUSDT') &(backtest_results_df['compare_symbol']=='ATOMUSDT')]

# %%
DOT_ALGO_backtest_df.head(10)
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 4        DOTUSDT       ALGOUSDT        1d          2         0.0         3
# 10       DOTUSDT       ALGOUSDT        1d          2         0.5         3
# 5        DOTUSDT       ALGOUSDT        1d          2         0.0         3
# 14       DOTUSDT       ALGOUSDT        1d          3         0.0         4
# 20       DOTUSDT       ALGOUSDT        1d          3         0.5         4
# 11       DOTUSDT       ALGOUSDT        1d          2         0.5         3
# 23       DOTUSDT       ALGOUSDT        1d          3         0.5         4
# 16       DOTUSDT       ALGOUSDT        1d          3         0.0         4
# 24       DOTUSDT       ALGOUSDT        1d          4         0.0         5
# 25       DOTUSDT       ALGOUSDT        1d          4         0.0         5
#
#     period  PnL_final
# 4       50    1739.63
# 10      50    1390.61
# 5       60    1366.17
# 14      30    1345.79
# 20      30    1037.88
# ...

# %%
DOT_ALGO_backtest_df.tail(10)
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 26       DOTUSDT       ALGOUSDT        1d          4         0.0         5
# 3        DOTUSDT       ALGOUSDT        1d          2         0.0         3
# 1        DOTUSDT       ALGOUSDT        1d          2         0.0         3
# 32       DOTUSDT       ALGOUSDT        1d          4         0.5         5
# 8        DOTUSDT       ALGOUSDT        1d          2         0.5         3
# 18       DOTUSDT       ALGOUSDT        1d          3         0.5         4
# 7        DOTUSDT       ALGOUSDT        1d          2         0.5         3
# 2        DOTUSDT       ALGOUSDT        1d          2         0.0         3
# 6        DOTUSDT       ALGOUSDT        1d          2         0.5         3
# 0        DOTUSDT       ALGOUSDT        1d          2         0.0         3
#
#     period  PnL_final
# 26      30       8.63
# 3       40      -3.03
# 1       20    -109.56
# 32      30    -109.74
# 8       30    -251.26
# ...

# %%
ADA_ALGO_backtest_df.head(10)
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 41       ADAUSDT       ALGOUSDT        1d          2         0.0         3
# 50       ADAUSDT       ALGOUSDT        1d          3         0.0         4
# 40       ADAUSDT       ALGOUSDT        1d          2         0.0         3
# 57       ADAUSDT       ALGOUSDT        1d          3         0.5         4
# 52       ADAUSDT       ALGOUSDT        1d          3         0.0         4
# 56       ADAUSDT       ALGOUSDT        1d          3         0.5         4
# 47       ADAUSDT       ALGOUSDT        1d          2         0.5         3
# 51       ADAUSDT       ALGOUSDT        1d          3         0.0         4
# 58       ADAUSDT       ALGOUSDT        1d          3         0.5         4
# 61       ADAUSDT       ALGOUSDT        1d          4         0.0         5
#
#     period  PnL_final
# 41      60    2802.12
# 50      30    2206.77
# 40      50    1650.16
# 57      40    1293.07
# 52      50    1179.35
# ...

# %%
ADA_ALGO_backtest_df.tail(10)
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 38       ADAUSDT       ALGOUSDT        1d          2         0.0         3
# 44       ADAUSDT       ALGOUSDT        1d          2         0.5         3
# 60       ADAUSDT       ALGOUSDT        1d          4         0.0         5
# 66       ADAUSDT       ALGOUSDT        1d          4         0.5         5
# 43       ADAUSDT       ALGOUSDT        1d          2         0.5         3
# 37       ADAUSDT       ALGOUSDT        1d          2         0.0         3
# 42       ADAUSDT       ALGOUSDT        1d          2         0.5         3
# 54       ADAUSDT       ALGOUSDT        1d          3         0.5         4
# 36       ADAUSDT       ALGOUSDT        1d          2         0.0         3
# 48       ADAUSDT       ALGOUSDT        1d          3         0.0         4
#
#     period  PnL_final
# 38      30     -24.84
# 44      30    -429.58
# 60      10    -540.89
# 66      10    -548.39
# 43      20    -590.49
# ...
