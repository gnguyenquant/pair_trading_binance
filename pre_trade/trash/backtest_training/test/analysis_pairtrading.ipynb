# %%
import pandas as pd

# %%
backtest_path='../../../data/backtest/training/'
backtest_results_df=pd.read_csv('{}backtest_training_2h.csv'.format(backtest_path))

# %%
backtest_results_df.sort_values(by='PnL_final',inplace=True,ascending=False)
backtest_results_df
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 118      AVAXUSDT       NEARUSDT        2h          2         0.5         3
# 22        DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 23        DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 15        DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 20        DOTUSDT       ALGOUSDT        2h          3         0.5         4
# ..            ...            ...       ...        ...         ...       ...
# 227       ETHUSDT        ADAUSDT        2h          2         0.5         3
# 219       ETHUSDT        ADAUSDT        2h          2         0.0         3
# 156      ALGOUSDT       ATOMUSDT        2h          3         0.0         4
# 221       ETHUSDT        ADAUSDT        2h          2         0.0         3
# 5         DOTUSDT       ALGOUSDT        2h          2         0.0         3
#
#      period  PnL_final
# 118      50    3167.45
# 22       50    2441.05
# 23       60    1956.99
# 15       40    1752.26
# 20       30    1688.77
# ..      ...        ...
# 227      60    -928.93
# 219      40    -938.52
# 156      10    -944.24
# 221      60   -1069.59
# 5        60   -1392.90
#
# [252 rows x 8 columns]

# %%
DOT_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='DOTUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
ETH_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ETHUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
ADA_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ADAUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
AVAX_NEAR_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='AVAXUSDT') &(backtest_results_df['compare_symbol']=='NEARUSDT')]
ALGO_ATOM_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ALGOUSDT') &(backtest_results_df['compare_symbol']=='ATOMUSDT')]
BNB_ALGO_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='BNBUSDT') &(backtest_results_df['compare_symbol']=='ALGOUSDT')]
ETH_ADA_backtest_df=backtest_results_df.loc[(backtest_results_df['chosen_symbol']=='ETHUSDT') &(backtest_results_df['compare_symbol']=='ADAUSDT')]

# %%
DOT_ALGO_backtest_df.head(10)
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 22       DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 23       DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 15       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 20       DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 14       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 21       DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 16       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 29       DOTUSDT       ALGOUSDT        2h          4         0.0         5
# 35       DOTUSDT       ALGOUSDT        2h          4         0.5         5
# 33       DOTUSDT       ALGOUSDT        2h          4         0.5         5
#
#     period  PnL_final
# 22      50    2441.05
# 23      60    1956.99
# 15      40    1752.26
# 20      30    1688.77
# 14      30    1393.71
# 21      40    1056.08
# 16      50     697.62
# 29      60     646.47
# 35      60     618.06
# 33      40     455.05

# %%
DOT_ALGO_backtest_df.tail(10)
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 13       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 12       DOTUSDT       ALGOUSDT        2h          3         0.0         4
# 24       DOTUSDT       ALGOUSDT        2h          4         0.0         5
# 4        DOTUSDT       ALGOUSDT        2h          2         0.0         3
# 19       DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 0        DOTUSDT       ALGOUSDT        2h          2         0.0         3
# 30       DOTUSDT       ALGOUSDT        2h          4         0.5         5
# 6        DOTUSDT       ALGOUSDT        2h          2         0.5         3
# 18       DOTUSDT       ALGOUSDT        2h          3         0.5         4
# 5        DOTUSDT       ALGOUSDT        2h          2         0.0         3
#
#     period  PnL_final
# 13      20    -155.30
# 12      10    -162.98
# 24      10    -323.30
# 4       50    -369.41
# 19      20    -408.16
# 0       10    -465.89
# 30      10    -497.10
# 6       10    -685.71
# 18      10    -750.59
# 5       60   -1392.90

# %%
ETH_ALGO_backtest_df.head()
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 59       ETHUSDT       ALGOUSDT        2h          3         0.5         4
# 64       ETHUSDT       ALGOUSDT        2h          4         0.0         5
# 65       ETHUSDT       ALGOUSDT        2h          4         0.0         5
# 52       ETHUSDT       ALGOUSDT        2h          3         0.0         4
# 71       ETHUSDT       ALGOUSDT        2h          4         0.5         5
#
#     period  PnL_final
# 59      60     456.24
# 64      50     141.92
# 65      60      49.52
# 52      50     -14.48
# 71      60     -24.77

# %%
ETH_ALGO_backtest_df.tail()
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 38       ETHUSDT       ALGOUSDT        2h          2         0.0         3
# 40       ETHUSDT       ALGOUSDT        2h          2         0.0         3
# 46       ETHUSDT       ALGOUSDT        2h          2         0.5         3
# 41       ETHUSDT       ALGOUSDT        2h          2         0.0         3
# 47       ETHUSDT       ALGOUSDT        2h          2         0.5         3
#
#     period  PnL_final
# 38      30    -592.88
# 40      50    -703.78
# 46      50    -724.95
# 41      60    -748.41
# 47      60    -756.72

# %%
ADA_ALGO_backtest_df.head()
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 81        ADAUSDT       ALGOUSDT        2h          2         0.5         3
# 98        ADAUSDT       ALGOUSDT        2h          4         0.0         5
# 97        ADAUSDT       ALGOUSDT        2h          4         0.0         5
# 104       ADAUSDT       ALGOUSDT        2h          4         0.5         5
# 103       ADAUSDT       ALGOUSDT        2h          4         0.5         5
#
#      period  PnL_final
# 81       40     -91.42
# 98       30    -144.28
# 97       20    -189.52
# 104      30    -238.52
# 103      20    -275.15

# %%
ADA_ALGO_backtest_df.tail()
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 85       ADAUSDT       ALGOUSDT        2h          3         0.0         4
# 79       ADAUSDT       ALGOUSDT        2h          2         0.5         3
# 76       ADAUSDT       ALGOUSDT        2h          2         0.0         3
# 73       ADAUSDT       ALGOUSDT        2h          2         0.0         3
# 89       ADAUSDT       ALGOUSDT        2h          3         0.0         4
#
#     period  PnL_final
# 85      20    -716.48
# 79      20    -756.15
# 76      50    -761.40
# 73      20    -792.55
# 89      60    -796.79

# %%
AVAX_NEAR_backtest_df.head()
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 118      AVAXUSDT       NEARUSDT        2h          2         0.5         3
# 117      AVAXUSDT       NEARUSDT        2h          2         0.5         3
# 110      AVAXUSDT       NEARUSDT        2h          2         0.0         3
# 119      AVAXUSDT       NEARUSDT        2h          2         0.5         3
# 130      AVAXUSDT       NEARUSDT        2h          3         0.5         4
#
#      period  PnL_final
# 118      50    3167.45
# 117      40    1125.30
# 110      30     851.87
# 119      60     769.14
# 130      50     564.12

# %%
AVAX_NEAR_backtest_df.tail()
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 132      AVAXUSDT       NEARUSDT        2h          4         0.0         5
# 138      AVAXUSDT       NEARUSDT        2h          4         0.5         5
# 126      AVAXUSDT       NEARUSDT        2h          3         0.5         4
# 143      AVAXUSDT       NEARUSDT        2h          4         0.5         5
# 120      AVAXUSDT       NEARUSDT        2h          3         0.0         4
#
#      period  PnL_final
# 132      10    -544.21
# 138      10    -568.47
# 126      10    -698.00
# 143      60    -724.93
# 120      10    -895.65

# %%
ALGO_ATOM_backtest_df.head()
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 166      ALGOUSDT       ATOMUSDT        2h          3         0.5         4
# 159      ALGOUSDT       ATOMUSDT        2h          3         0.0         4
# 161      ALGOUSDT       ATOMUSDT        2h          3         0.0         4
# 170      ALGOUSDT       ATOMUSDT        2h          4         0.0         5
# 155      ALGOUSDT       ATOMUSDT        2h          2         0.5         3
#
#      period  PnL_final
# 166      50    1060.15
# 159      40     790.14
# 161      60     706.23
# 170      30     646.86
# 155      60     588.30

# %%
ALGO_ATOM_backtest_df.tail()
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  takeprofit  stoploss  \
# 144      ALGOUSDT       ATOMUSDT        2h          2         0.0         3
# 162      ALGOUSDT       ATOMUSDT        2h          3         0.5         4
# 174      ALGOUSDT       ATOMUSDT        2h          4         0.5         5
# 168      ALGOUSDT       ATOMUSDT        2h          4         0.0         5
# 156      ALGOUSDT       ATOMUSDT        2h          3         0.0         4
#
#      period  PnL_final
# 144      10    -633.95
# 162      10    -706.38
# 174      10    -791.64
# 168      10    -853.19
# 156      10    -944.24
