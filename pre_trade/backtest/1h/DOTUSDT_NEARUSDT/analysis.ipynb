# %%
import pandas as pd
from PIL import Image

# %%
training_path='results/training/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
training_results_df=pd.read_csv('{}backtest_training_1h.csv'.format(training_path),names=header)
training_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)

# %%
training_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0        DOTUSDT       NEARUSDT        1h          2      10    -323.34
# 1        DOTUSDT       NEARUSDT        1h          2      20    -658.01
# 2        DOTUSDT       NEARUSDT        1h          2      30     114.84
# 3        DOTUSDT       NEARUSDT        1h          2      40     249.27
# 4        DOTUSDT       NEARUSDT        1h          2      50     188.86
# 5        DOTUSDT       NEARUSDT        1h          2      60    -193.19
# 6        DOTUSDT       NEARUSDT        1h          3      10     902.69
# 7        DOTUSDT       NEARUSDT        1h          3      20    -443.25
# 11       DOTUSDT       NEARUSDT        1h          3      60     796.07
# 12       DOTUSDT       NEARUSDT        1h          4      10    -229.53
# 13       DOTUSDT       NEARUSDT        1h          4      20    -486.36
# 14       DOTUSDT       NEARUSDT        1h          4      30     107.71
# 15       DOTUSDT       NEARUSDT        1h          4      40     228.01
# 16       DOTUSDT       NEARUSDT        1h          4      50     225.49
# 17       DOTUSDT       NEARUSDT        1h          4      60    1208.78
# 18       DOTUSDT       NEARUSDT        1h          3      30    -197.40
# 19       DOTUSDT       NEARUSDT        1h          3      31     474.29
# 20       DOTUSDT       NEARUSDT        1h          3      32     272.07
# 21       DOTUSDT       NEARUSDT        1h          3      33     405.99
# 22       DOTUSDT       NEARUSDT        1h          3      34     236.06
# 23       DOTUSDT       NEARUSDT        1h          3      35     653.87
# 24       DOTUSDT       NEARUSDT        1h          3      36     555.96
# 25       DOTUSDT       NEARUSDT        1h          3      37     316.78
# 26       DOTUSDT       NEARUSDT        1h          3      38     161.49
# 27       DOTUSDT       NEARUSDT        1h          3      39    1015.09
# 28       DOTUSDT       NEARUSDT        1h          3      40    1607.05
# 29       DOTUSDT       NEARUSDT        1h          3      41     688.92
# 30       DOTUSDT       NEARUSDT        1h          3      42     793.77
# 31       DOTUSDT       NEARUSDT        1h          3      43     706.69
# 32       DOTUSDT       NEARUSDT        1h          3      44     670.08
# 33       DOTUSDT       NEARUSDT        1h          3      45     633.58
# 34       DOTUSDT       NEARUSDT        1h          3      46     380.87
# 35       DOTUSDT       NEARUSDT        1h          3      47     359.77
# 36       DOTUSDT       NEARUSDT        1h          3      48     368.78
# 37       DOTUSDT       NEARUSDT        1h          3      49     523.00
# 38       DOTUSDT       NEARUSDT        1h          3      50     431.10
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0          -0.11              0.51          1.85
# 1          -0.49              0.88          0.53
# 2           0.34              0.81          3.56
# 3           0.41              0.81          1.61
# 4           0.36              0.86          2.06
# 5           0.14              0.81          1.64
# 6           0.83              0.65          0.38
# 7          -0.44              0.69          0.45
# 11          0.89              0.45          0.15
# 12         -0.27              0.23          0.72
# 13         -0.84              0.45          0.12
# 14          0.30              0.15          0.58
# 15          0.52              0.20          0.27
# 16          0.49              0.17          0.22
# 17          1.33              0.20          0.04
# 18         -0.09              0.42          0.70
# 19          0.64              0.24          0.34
# 20          0.48              0.29          0.56
# 21          0.62              0.25          0.40
# 22          0.43              0.25          0.68
# 23          0.81              0.27          0.26
# 24          0.70              0.31          0.29
# 25          0.50              0.32          0.47
# 26          0.35              0.32          0.88
# 27          1.08              0.32          0.17
# 28          1.43              0.22          0.12
# 29          0.85              0.25          0.22
# 30          0.96              0.22          0.20
# 31          0.86              0.20          0.21
# 32          0.82              0.19          0.23
# 33          0.78              0.19          0.24
# 34          0.57              0.20          0.36
# 35          0.55              0.27          0.37
# 36          0.55              0.26          0.35
# 37          0.69              0.28          0.26
# 38          0.61              0.28          0.32

# %%
figures_path=training_path+'figures/'
PnL_path=training_path+'PnL/'
texts=training_path+'texts/'
chosen_symbol='DOTUSDT'
compare_symbol='NEARUSDT'
timeframe='1h'
threshold=2
period=20
im=Image.open('{}{}_{}_{}_{}_{}.png'.format(PnL_path,chosen_symbol,compare_symbol,timeframe,threshold,period))
im.show()

# %%
training_results_df.sort_values(by=['threshold','period'],inplace=True)

# %%
training_results_df.loc[training_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
test_path='results/test/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
test_results_df=pd.read_csv('{}backtest_test_1h.csv'.format(test_path),names=header)
test_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)

# %%
test_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0        DOTUSDT       NEARUSDT        1h          3      30   -1196.84
# 1        DOTUSDT       NEARUSDT        1h          3      31   -1282.61
# 2        DOTUSDT       NEARUSDT        1h          3      32   -1253.06
# 3        DOTUSDT       NEARUSDT        1h          3      33   -1215.93
# 4        DOTUSDT       NEARUSDT        1h          3      34   -1146.08
# 5        DOTUSDT       NEARUSDT        1h          3      35   -1159.96
# 6        DOTUSDT       NEARUSDT        1h          3      36   -1162.21
# 7        DOTUSDT       NEARUSDT        1h          3      37   -1058.21
# 8        DOTUSDT       NEARUSDT        1h          3      38   -1043.34
# 9        DOTUSDT       NEARUSDT        1h          3      39   -1071.10
# 10       DOTUSDT       NEARUSDT        1h          3      40    -989.67
# 11       DOTUSDT       NEARUSDT        1h          3      41    -992.16
# 12       DOTUSDT       NEARUSDT        1h          3      42   -1070.08
# 13       DOTUSDT       NEARUSDT        1h          3      43   -1051.83
# 14       DOTUSDT       NEARUSDT        1h          3      44   -1076.30
# 15       DOTUSDT       NEARUSDT        1h          3      45   -1003.18
# 16       DOTUSDT       NEARUSDT        1h          3      46   -1004.51
# 17       DOTUSDT       NEARUSDT        1h          3      47   -1048.72
# 18       DOTUSDT       NEARUSDT        1h          3      48    -944.98
# 19       DOTUSDT       NEARUSDT        1h          3      49    -951.77
# 20       DOTUSDT       NEARUSDT        1h          3      50    -889.62
# 21       DOTUSDT       NEARUSDT        1h          3      51    -922.21
# 22       DOTUSDT       NEARUSDT        1h          3      52    -980.43
# 23       DOTUSDT       NEARUSDT        1h          3      53    -990.99
# 24       DOTUSDT       NEARUSDT        1h          3      54    -955.27
# 25       DOTUSDT       NEARUSDT        1h          3      55    -972.52
# 26       DOTUSDT       NEARUSDT        1h          3      56    -808.67
# 27       DOTUSDT       NEARUSDT        1h          3      57    -840.17
# 28       DOTUSDT       NEARUSDT        1h          3      58    -727.43
# 29       DOTUSDT       NEARUSDT        1h          3      59    -372.49
# 30       DOTUSDT       NEARUSDT        1h          3      60    -519.47
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0          -1.23              0.97          0.07
# 1          -1.37              1.14          0.06
# 2          -1.52              1.12          0.06
# 3          -1.40              1.05          0.06
# 4          -1.12              0.96          0.07
# 5          -1.21              0.99          0.07
# 6          -1.19              0.99          0.07
# 7          -1.01              0.86          0.09
# 8          -0.85              0.83          0.09
# 9          -1.33              0.95          0.09
# 10         -1.19              0.85          0.10
# 11         -1.28              0.82          0.09
# 12         -1.41              0.91          0.08
# 13         -1.33              0.86          0.08
# 14         -1.41              0.89          0.08
# 15         -1.14              0.80          0.08
# 16         -1.36              0.79          0.08
# 17         -1.48              0.85          0.08
# 18         -1.17              0.73          0.09
# 19         -1.18              0.75          0.09
# 20         -1.13              0.67          0.10
# 21         -1.22              0.68          0.08
# 22         -1.10              0.71          0.08
# 23         -0.97              0.71          0.08
# 24         -0.93              0.66          0.08
# 25         -0.93              0.67          0.08
# 26         -0.58              0.49          0.10
# 27         -0.67              0.52          0.10
# 28         -0.50              0.46          0.12
# 29         -0.04              0.49          0.26
# 30         -0.17              0.50          0.17

# %%
test_results_df.loc[test_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>
