# %%
import pandas as pd

# %%
training_path='results/training/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
training_results_df=pd.read_csv('{}backtest_training_1h.csv'.format(training_path),names=header)
training_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)

# %%
training_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0        DOTUSDT       ALGOUSDT        1h          2      30     647.81
# 1        DOTUSDT       ALGOUSDT        1h          2      31     653.53
# 2        DOTUSDT       ALGOUSDT        1h          2      32    1283.15
# 3        DOTUSDT       ALGOUSDT        1h          2      33    1798.37
# 4        DOTUSDT       ALGOUSDT        1h          2      34    2445.23
# ..           ...            ...       ...        ...     ...        ...
# 88       DOTUSDT       ALGOUSDT        1h          4      56     -71.16
# 89       DOTUSDT       ALGOUSDT        1h          4      57     -36.64
# 90       DOTUSDT       ALGOUSDT        1h          4      58     -62.17
# 91       DOTUSDT       ALGOUSDT        1h          4      59     -26.67
# 92       DOTUSDT       ALGOUSDT        1h          4      60      -2.53
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0           0.74              0.85          0.46
# 1           0.75              0.78          0.46
# 2           0.99              0.68          0.25
# 3           1.13              0.55          0.20
# 4           1.29              0.48          0.16
# ..           ...               ...           ...
# 88         -0.05              0.28          0.33
# 89          0.02              0.28          0.64
# 90         -0.01              0.38          0.44
# 91          0.06              0.40          1.04
# 92          0.10              0.40         11.06
#
# [93 rows x 9 columns]

# %%
training_results_df.sort_values(by=['threshold','period'],inplace=True)

# %%
training_results_df.loc[training_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
training_results_df.loc[(training_results_df['period']>42) &(training_results_df['period']<57) &(training_results_df['threshold']==3)]
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 44       DOTUSDT       ALGOUSDT        1h          3      43     520.89
# 45       DOTUSDT       ALGOUSDT        1h          3      44    1015.53
# 46       DOTUSDT       ALGOUSDT        1h          3      45    1368.63
# 47       DOTUSDT       ALGOUSDT        1h          3      46    1934.51
# 48       DOTUSDT       ALGOUSDT        1h          3      47    2596.07
# 49       DOTUSDT       ALGOUSDT        1h          3      48    2514.02
# 50       DOTUSDT       ALGOUSDT        1h          3      49    2156.78
# 51       DOTUSDT       ALGOUSDT        1h          3      50    2008.05
# 52       DOTUSDT       ALGOUSDT        1h          3      51    1699.62
# 53       DOTUSDT       ALGOUSDT        1h          3      52    1713.80
# 54       DOTUSDT       ALGOUSDT        1h          3      53    1855.37
# 55       DOTUSDT       ALGOUSDT        1h          3      54    1731.62
# 56       DOTUSDT       ALGOUSDT        1h          3      55     768.91
# 57       DOTUSDT       ALGOUSDT        1h          3      56     386.56
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 44          0.74              0.28          0.22
# 45          1.10              0.24          0.12
# 46          1.33              0.23          0.09
# 47          1.55              0.25          0.07
# 48          1.81              0.27          0.06
# 49          1.94              0.23          0.06
# 50          1.75              0.24          0.06
# 51          1.75              0.21          0.07
# 52          1.62              0.23          0.08
# 53          1.43              0.26          0.07
# 54          1.49              0.27          0.07
# 55          1.47              0.24          0.07
# 56          0.93              0.35          0.13
# 57          0.57              0.46          0.25

# %%
test_path='results/test/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
test_results_df=pd.read_csv('{}backtest_test_1h.csv'.format(test_path),names=header)
test_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)

# %%
test_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0        DOTUSDT       ALGOUSDT        1h          3      42     241.09
# 1        DOTUSDT       ALGOUSDT        1h          3      43     192.50
# 2        DOTUSDT       ALGOUSDT        1h          3      44      87.19
# 3        DOTUSDT       ALGOUSDT        1h          3      45    -143.27
# 4        DOTUSDT       ALGOUSDT        1h          3      46    -152.04
# 5        DOTUSDT       ALGOUSDT        1h          3      47    -134.42
# 6        DOTUSDT       ALGOUSDT        1h          3      48     111.63
# 7        DOTUSDT       ALGOUSDT        1h          3      49      42.11
# 8        DOTUSDT       ALGOUSDT        1h          3      50     -22.29
# 9        DOTUSDT       ALGOUSDT        1h          3      51     -40.32
# 10       DOTUSDT       ALGOUSDT        1h          3      52     -52.99
# 11       DOTUSDT       ALGOUSDT        1h          3      53     149.70
# 12       DOTUSDT       ALGOUSDT        1h          3      54     218.16
# 13       DOTUSDT       ALGOUSDT        1h          3      55     229.62
# 14       DOTUSDT       ALGOUSDT        1h          3      56     210.27
# 15       DOTUSDT       ALGOUSDT        1h          3      57     291.72
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0           0.46              0.34          0.55
# 1           0.40              0.31          0.66
# 2           0.26              0.29          1.34
# 3          -0.12              0.27          0.74
# 4          -0.16              0.25          0.71
# 5          -0.12              0.26          0.85
# 6           0.27              0.25          1.18
# 7           0.18              0.25          2.93
# 8           0.09              0.23          5.27
# 9           0.06              0.22          2.85
# 10          0.05              0.26          2.15
# 11          0.30              0.26          0.85
# 12          0.39              0.23          0.58
# 13          0.41              0.24          0.52
# 14          0.39              0.24          0.53
# 15          0.48              0.24          0.39

# %%
test_results_df.loc[test_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>
