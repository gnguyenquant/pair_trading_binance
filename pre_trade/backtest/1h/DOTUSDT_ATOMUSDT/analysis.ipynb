# %%
import pandas as pd

# %%
training_path='results/training/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
training_results_df=pd.read_csv('{}backtest_training_1h.csv'.format(training_path),names=header)
training_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)

# %%
training_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0        DOTUSDT       ATOMUSDT        1h          2      30    -501.78
# 1        DOTUSDT       ATOMUSDT        1h          2      31    -120.92
# 2        DOTUSDT       ATOMUSDT        1h          2      32      10.80
# 3        DOTUSDT       ATOMUSDT        1h          2      33     236.31
# 4        DOTUSDT       ATOMUSDT        1h          2      34     401.27
# ..           ...            ...       ...        ...     ...        ...
# 88       DOTUSDT       ATOMUSDT        1h          4      56     455.02
# 89       DOTUSDT       ATOMUSDT        1h          4      57     218.83
# 90       DOTUSDT       ATOMUSDT        1h          4      58     142.59
# 91       DOTUSDT       ATOMUSDT        1h          4      59     157.44
# 92       DOTUSDT       ATOMUSDT        1h          4      60     184.97
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0          -0.27              0.71          0.75
# 1           0.16              0.65          3.79
# 2           0.23              0.82         47.20
# 3           0.38              0.65          2.23
# 4           0.47              0.64          1.35
# ..           ...               ...           ...
# 88          1.15              0.12          0.08
# 89          0.64              0.12          0.17
# 90          0.43              0.12          0.26
# 91          0.47              0.12          0.24
# 92          0.55              0.12          0.20
#
# [93 rows x 9 columns]

# %%
training_results_df.sort_values(by=['threshold','period'],inplace=True)

# %%
training_results_df.loc[training_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
training_results_df.loc[(training_results_df['period']>=50) &(training_results_df['period']<=60) &(training_results_df['threshold']==3)]
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 51       DOTUSDT       ATOMUSDT        1h          3      50    2664.12
# 52       DOTUSDT       ATOMUSDT        1h          3      51    3374.32
# 53       DOTUSDT       ATOMUSDT        1h          3      52    4039.70
# 54       DOTUSDT       ATOMUSDT        1h          3      53    3450.61
# 55       DOTUSDT       ATOMUSDT        1h          3      54    3387.73
# 56       DOTUSDT       ATOMUSDT        1h          3      55    4221.49
# 57       DOTUSDT       ATOMUSDT        1h          3      56    4503.29
# 58       DOTUSDT       ATOMUSDT        1h          3      57    3426.99
# 59       DOTUSDT       ATOMUSDT        1h          3      58    3700.46
# 60       DOTUSDT       ATOMUSDT        1h          3      59    3805.00
# 61       DOTUSDT       ATOMUSDT        1h          3      60    3585.47
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 51          1.31              0.41          0.08
# 52          1.47              0.40          0.06
# 53          1.55              0.46          0.06
# 54          1.47              0.44          0.06
# 55          1.47              0.44          0.06
# 56          1.63              0.45          0.05
# 57          1.68              0.45          0.05
# 58          1.46              0.46          0.07
# 59          1.50              0.44          0.06
# 60          1.51              0.44          0.06
# 61          1.48              0.44          0.06

# %%
test_path='results/test/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
test_results_df=pd.read_csv('{}backtest_test_1h.csv'.format(test_path),names=header)
test_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)

# %%
test_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0        DOTUSDT       ATOMUSDT        1h          3      50     974.16
# 1        DOTUSDT       ATOMUSDT        1h          3      51    1074.51
# 2        DOTUSDT       ATOMUSDT        1h          3      52    1101.52
# 3        DOTUSDT       ATOMUSDT        1h          3      53    1653.11
# 4        DOTUSDT       ATOMUSDT        1h          3      54    2136.59
# 5        DOTUSDT       ATOMUSDT        1h          3      55    1577.60
# 6        DOTUSDT       ATOMUSDT        1h          3      56    1768.92
# 7        DOTUSDT       ATOMUSDT        1h          3      57    1647.17
# 8        DOTUSDT       ATOMUSDT        1h          3      58    1634.74
# 9        DOTUSDT       ATOMUSDT        1h          3      59    2327.40
# 10       DOTUSDT       ATOMUSDT        1h          3      60    2264.42
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0           1.14              0.22          0.15
# 1           1.20              0.18          0.14
# 2           1.22              0.17          0.13
# 3           1.55              0.17          0.09
# 4           1.73              0.18          0.08
# 5           1.45              0.21          0.10
# 6           1.55              0.18          0.09
# 7           1.49              0.22          0.09
# 8           1.50              0.22          0.09
# 9           1.77              0.23          0.07
# 10          1.75              0.23          0.07

# %%
test_results_df.loc[test_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>
