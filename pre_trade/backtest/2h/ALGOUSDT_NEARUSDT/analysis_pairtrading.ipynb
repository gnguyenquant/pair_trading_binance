# %%
import pandas as pd

# %%
training_path='results/training/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
training_results_df=pd.read_csv('{}backtest_training_2h.csv'.format(training_path),names=header)
#backtest_results_df.columns['chosen_symbol','compare_symbol','timeframe','threshold','takeprofit','stoploss','period','PnL_final']
training_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)

# %%
training_results_df.sort_values(by=['threshold','period'],inplace=True)
training_results_df
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0        ALGOUSDT       NEARUSDT        2h          2      20    3052.53
# 1        ALGOUSDT       NEARUSDT        2h          2      21    2114.55
# 2        ALGOUSDT       NEARUSDT        2h          2      22    2834.37
# 3        ALGOUSDT       NEARUSDT        2h          2      23    1655.35
# 4        ALGOUSDT       NEARUSDT        2h          2      24     716.66
# ..            ...            ...       ...        ...     ...        ...
# 118      ALGOUSDT       NEARUSDT        2h          4      56    1239.50
# 119      ALGOUSDT       NEARUSDT        2h          4      57    1185.50
# 120      ALGOUSDT       NEARUSDT        2h          4      58    1373.74
# 121      ALGOUSDT       NEARUSDT        2h          4      59    1469.84
# 122      ALGOUSDT       NEARUSDT        2h          4      60    1529.80
#
#      Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0            1.97              0.32          0.17
# 1            1.59              0.32          0.22
# 2            1.84              0.33          0.16
# 3            1.44              0.29          0.23
# 4            0.86              0.57          0.43
# ..            ...               ...           ...
# 118          2.10              0.12          0.04
# 119          2.05              0.12          0.04
# 120          2.20              0.12          0.03
# 121          2.28              0.11          0.03
# 122          2.33              0.11          0.03
#
# [123 rows x 9 columns]

# %%
training_results_df.loc[training_results_df['threshold']==2].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
training_results_df.loc[(training_results_df['threshold']==2)&(training_results_df['period']>=35)&(training_results_df['period']<=45)]
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 15      ALGOUSDT       NEARUSDT        2h          2      35    3762.57
# 16      ALGOUSDT       NEARUSDT        2h          2      36    4112.62
# 17      ALGOUSDT       NEARUSDT        2h          2      37    6944.81
# 18      ALGOUSDT       NEARUSDT        2h          2      38    9169.09
# 19      ALGOUSDT       NEARUSDT        2h          2      39    9365.42
# 20      ALGOUSDT       NEARUSDT        2h          2      40    8447.32
# 21      ALGOUSDT       NEARUSDT        2h          2      41    6813.48
# 22      ALGOUSDT       NEARUSDT        2h          2      42    6186.85
# 23      ALGOUSDT       NEARUSDT        2h          2      43    5383.73
# 24      ALGOUSDT       NEARUSDT        2h          2      44    4523.81
# 25      ALGOUSDT       NEARUSDT        2h          2      45    3412.62
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 15          2.43              0.20          0.11
# 16          2.48              0.27          0.10
# 17          3.14              0.19          0.08
# 18          3.55              0.19          0.07
# 19          3.40              0.22          0.07
# 20          3.14              0.24          0.07
# 21          2.92              0.21          0.07
# 22          2.80              0.21          0.08
# 23          2.60              0.20          0.09
# 24          2.39              0.20          0.09
# 25          2.11              0.19          0.11

# %%
training_results_df.loc[training_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
training_results_df.loc[(training_results_df['threshold']==3)&(training_results_df['period']>=35)&(training_results_df['period']<=45)]
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 56      ALGOUSDT       NEARUSDT        2h          3      35     312.60
# 57      ALGOUSDT       NEARUSDT        2h          3      36    1852.37
# 58      ALGOUSDT       NEARUSDT        2h          3      37    2858.15
# 59      ALGOUSDT       NEARUSDT        2h          3      38    2149.76
# 60      ALGOUSDT       NEARUSDT        2h          3      39    1885.11
# 61      ALGOUSDT       NEARUSDT        2h          3      40    1663.73
# 62      ALGOUSDT       NEARUSDT        2h          3      41    1817.94
# 63      ALGOUSDT       NEARUSDT        2h          3      42    1475.12
# 64      ALGOUSDT       NEARUSDT        2h          3      43    1593.44
# 65      ALGOUSDT       NEARUSDT        2h          3      44    1418.87
# 66      ALGOUSDT       NEARUSDT        2h          3      45    1147.94
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 56          0.51              0.25          0.34
# 57          2.32              0.18          0.08
# 58          2.86              0.17          0.06
# 59          2.46              0.14          0.07
# 60          2.09              0.14          0.07
# 61          1.86              0.14          0.08
# 62          1.99              0.13          0.08
# 63          1.77              0.13          0.09
# 64          1.92              0.12          0.08
# 65          1.77              0.15          0.09
# 66          1.52              0.15          0.10

# %%
training_results_df.loc[training_results_df['threshold']==4].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 56      ALGOUSDT       NEARUSDT        2h          3      35     312.60
# 57      ALGOUSDT       NEARUSDT        2h          3      36    1852.37
# 58      ALGOUSDT       NEARUSDT        2h          3      37    2858.15
# 59      ALGOUSDT       NEARUSDT        2h          3      38    2149.76
# 60      ALGOUSDT       NEARUSDT        2h          3      39    1885.11
# 61      ALGOUSDT       NEARUSDT        2h          3      40    1663.73
# 62      ALGOUSDT       NEARUSDT        2h          3      41    1817.94
# 63      ALGOUSDT       NEARUSDT        2h          3      42    1475.12
# 64      ALGOUSDT       NEARUSDT        2h          3      43    1593.44
# 65      ALGOUSDT       NEARUSDT        2h          3      44    1418.87
# 66      ALGOUSDT       NEARUSDT        2h          3      45    1147.94
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 56          0.51              0.25          0.34
# 57          2.32              0.18          0.08
# 58          2.86              0.17          0.06
# 59          2.46              0.14          0.07
# 60          2.09              0.14          0.07
# 61          1.86              0.14          0.08
# 62          1.99              0.13          0.08
# 63          1.77              0.13          0.09
# 64          1.92              0.12          0.08
# 65          1.77              0.15          0.09
# 66          1.52              0.15          0.10

# %%
test_path='results/test/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
test_results_df=pd.read_csv('{}backtest_test_2h.csv'.format(test_path),names=header)
#backtest_results_df.columns['chosen_symbol','compare_symbol','timeframe','threshold','takeprofit','stoploss','period','PnL_final']
#test_results_df=test_results_df.loc[test_results_df['threshold']==2]
test_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)
test_results_df.sort_values(by=['threshold','period'],inplace=True)

# %%
test_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0       ALGOUSDT       NEARUSDT        2h          2      35    1440.21
# 1       ALGOUSDT       NEARUSDT        2h          2      36    1638.05
# 2       ALGOUSDT       NEARUSDT        2h          2      37    2060.29
# 3       ALGOUSDT       NEARUSDT        2h          2      38    2171.81
# 4       ALGOUSDT       NEARUSDT        2h          2      39    3591.69
# 5       ALGOUSDT       NEARUSDT        2h          2      40    2783.27
# 6       ALGOUSDT       NEARUSDT        2h          2      41    2821.22
# 7       ALGOUSDT       NEARUSDT        2h          2      42    3097.13
# 8       ALGOUSDT       NEARUSDT        2h          2      43    3118.68
# 9       ALGOUSDT       NEARUSDT        2h          2      44    3235.60
# 10      ALGOUSDT       NEARUSDT        2h          2      45    3479.89
# 11      ALGOUSDT       NEARUSDT        2h          3      35     325.11
# 12      ALGOUSDT       NEARUSDT        2h          3      36     506.99
# 13      ALGOUSDT       NEARUSDT        2h          3      37     496.90
# 14      ALGOUSDT       NEARUSDT        2h          3      38     716.28
# 15      ALGOUSDT       NEARUSDT        2h          3      39    1266.27
# 16      ALGOUSDT       NEARUSDT        2h          3      40    1503.12
# 17      ALGOUSDT       NEARUSDT        2h          3      41    1298.30
# 18      ALGOUSDT       NEARUSDT        2h          3      42     751.27
# 19      ALGOUSDT       NEARUSDT        2h          3      43     986.76
# 20      ALGOUSDT       NEARUSDT        2h          3      44    1418.73
# 21      ALGOUSDT       NEARUSDT        2h          3      45    1295.54
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0           1.21              0.29          0.25
# 1           1.31              0.39          0.25
# 2           1.48              0.37          0.21
# 3           1.55              0.38          0.20
# 4           2.16              0.37          0.13
# 5           1.90              0.31          0.15
# 6           1.87              0.32          0.15
# 7           1.95              0.35          0.14
# 8           1.98              0.32          0.13
# 9           1.96              0.32          0.13
# 10          2.07              0.33          0.12
# 11          0.49              0.31          0.37
# 12          0.68              0.32          0.24
# 13          0.66              0.40          0.24
# 14          0.87              0.37          0.17
# 15          1.40              0.20          0.09
# 16          1.48              0.22          0.08
# 17          1.37              0.21          0.09
# 18          0.92              0.24          0.14
# 19          1.15              0.20          0.12
# 20          1.55              0.20          0.09
# 21          1.52              0.15          0.09

# %%
test_results_df.loc[test_results_df['threshold']==2].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
test_results_df.loc[test_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
test_results_df.loc[test_results_df['threshold']==4].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>
