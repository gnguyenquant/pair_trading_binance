# %%
import pandas as pd

# %%
training_path='results/training/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
training_results_df=pd.read_csv('{}backtest_training_2h.csv'.format(training_path),names=header)
#backtest_results_df.columns['chosen_symbol','compare_symbol','timeframe','threshold','takeprofit','stoploss','period','PnL_final']
training_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)

# %%
training_results_df.sort_values(by=['threshold','period'],inplace=True)
training_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 51      AVAXUSDT       ATOMUSDT        2h          2      20    1205.61
# 52      AVAXUSDT       ATOMUSDT        2h          2      21    1622.94
# 53      AVAXUSDT       ATOMUSDT        2h          2      22    1531.16
# 54      AVAXUSDT       ATOMUSDT        2h          2      23    1516.40
# 55      AVAXUSDT       ATOMUSDT        2h          2      24    1440.16
# 56      AVAXUSDT       ATOMUSDT        2h          2      25    1151.42
# 57      AVAXUSDT       ATOMUSDT        2h          2      26    1305.77
# 58      AVAXUSDT       ATOMUSDT        2h          2      27    1767.48
# 59      AVAXUSDT       ATOMUSDT        2h          2      28    1440.05
# 60      AVAXUSDT       ATOMUSDT        2h          2      29    2393.63
# 61      AVAXUSDT       ATOMUSDT        2h          2      30    2016.76
# 62      AVAXUSDT       ATOMUSDT        2h          2      31    2061.48
# 63      AVAXUSDT       ATOMUSDT        2h          2      32    1253.17
# 2       AVAXUSDT       ATOMUSDT        2h          2      34    1420.59
# 27      AVAXUSDT       ATOMUSDT        2h          2      35     975.88
# 3       AVAXUSDT       ATOMUSDT        2h          2      39     830.41
# 28      AVAXUSDT       ATOMUSDT        2h          2      40    1117.67
# 4       AVAXUSDT       ATOMUSDT        2h          2      44    2189.65
# 29      AVAXUSDT       ATOMUSDT        2h          2      45    1022.59
# 5       AVAXUSDT       ATOMUSDT        2h          2      49    1398.18
# 30      AVAXUSDT       ATOMUSDT        2h          2      50    1338.34
# 6       AVAXUSDT       ATOMUSDT        2h          2      54    1800.31
# 31      AVAXUSDT       ATOMUSDT        2h          2      55    1837.89
# 7       AVAXUSDT       ATOMUSDT        2h          2      59    1763.61
# 32      AVAXUSDT       ATOMUSDT        2h          2      60    1876.96
# 33      AVAXUSDT       ATOMUSDT        2h          3      20     688.27
# 8       AVAXUSDT       ATOMUSDT        2h          3      24     740.42
# 34      AVAXUSDT       ATOMUSDT        2h          3      25     734.02
# 9       AVAXUSDT       ATOMUSDT        2h          3      29    1169.46
# 35      AVAXUSDT       ATOMUSDT        2h          3      30    1237.89
# 10      AVAXUSDT       ATOMUSDT        2h          3      34     571.03
# 36      AVAXUSDT       ATOMUSDT        2h          3      35     640.31
# 11      AVAXUSDT       ATOMUSDT        2h          3      39     999.53
# 37      AVAXUSDT       ATOMUSDT        2h          3      40    1116.83
# 12      AVAXUSDT       ATOMUSDT        2h          3      44    1865.89
# 38      AVAXUSDT       ATOMUSDT        2h          3      45    1490.42
# 13      AVAXUSDT       ATOMUSDT        2h          3      49    2962.23
# 39      AVAXUSDT       ATOMUSDT        2h          3      50    3887.82
# 14      AVAXUSDT       ATOMUSDT        2h          3      54    1270.16
# 40      AVAXUSDT       ATOMUSDT        2h          3      55    1405.69
# 15      AVAXUSDT       ATOMUSDT        2h          3      59    2401.10
# 41      AVAXUSDT       ATOMUSDT        2h          3      60    2313.98
# 42      AVAXUSDT       ATOMUSDT        2h          4      20     254.76
# 16      AVAXUSDT       ATOMUSDT        2h          4      24    1081.93
# 43      AVAXUSDT       ATOMUSDT        2h          4      25    1222.96
# 17      AVAXUSDT       ATOMUSDT        2h          4      29    1648.00
# 44      AVAXUSDT       ATOMUSDT        2h          4      30    1677.56
# 18      AVAXUSDT       ATOMUSDT        2h          4      34    1144.04
# 45      AVAXUSDT       ATOMUSDT        2h          4      35    1023.26
# 19      AVAXUSDT       ATOMUSDT        2h          4      39     627.34
# 46      AVAXUSDT       ATOMUSDT        2h          4      40     541.15
# 20      AVAXUSDT       ATOMUSDT        2h          4      44     682.63
# 47      AVAXUSDT       ATOMUSDT        2h          4      45     652.80
# 21      AVAXUSDT       ATOMUSDT        2h          4      49     685.51
# 48      AVAXUSDT       ATOMUSDT        2h          4      50     753.83
# 22      AVAXUSDT       ATOMUSDT        2h          4      54     652.02
# 49      AVAXUSDT       ATOMUSDT        2h          4      55     655.33
# 23      AVAXUSDT       ATOMUSDT        2h          4      59     608.22
# 50      AVAXUSDT       ATOMUSDT        2h          4      60     647.31
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 51          1.28              0.36          0.32
# 52          1.50              0.36          0.27
# 53          1.51              0.34          0.27
# 54          1.50              0.35          0.26
# 55          1.80              0.25          0.22
# 56          1.50              0.24          0.25
# 57          1.72              0.28          0.21
# 58          1.92              0.21          0.16
# 59          1.53              0.33          0.20
# 60          2.35              0.20          0.13
# 61          1.98              0.26          0.15
# 62          2.09              0.21          0.15
# 63          1.26              0.34          0.21
# 2           1.40              0.33          0.18
# 27          1.17              0.25          0.23
# 3           1.09              0.28          0.23
# 28          1.32              0.22          0.19
# 4           1.84              0.26          0.11
# 29          1.26              0.19          0.19
# 5           1.38              0.32          0.15
# 30          1.37              0.27          0.15
# 6           1.81              0.34          0.12
# 31          1.81              0.31          0.12
# 7           1.66              0.34          0.13
# 32          1.72              0.39          0.13
# 33          1.10              0.18          0.19
# 8           1.44              0.21          0.15
# 34          1.36              0.18          0.14
# 9           1.94              0.19          0.08
# 35          2.07              0.21          0.07
# 10          1.08              0.40          0.12
# 36          1.19              0.35          0.11
# 11          1.63              0.29          0.07
# 37          1.74              0.31          0.06
# 12          1.82              0.49          0.03
# 38          1.58              0.49          0.04
# 13          2.24              0.33          0.02
# 39          2.50              0.30          0.02
# 14          1.48              0.35          0.04
# 40          1.57              0.35          0.04
# 15          2.01              0.32          0.02
# 41          1.94              0.33          0.02
# 42          0.76              0.18          0.15
# 16          2.40              0.09          0.04
# 43          3.23              0.04          0.03
# 17          3.60              0.03          0.02
# 44          3.50              0.03          0.02
# 18          1.90              0.23          0.02
# 45          1.77              0.23          0.03
# 19          1.11              0.26          0.04
# 46          1.01              0.26          0.04
# 20          2.10              0.03          0.02
# 47          2.05              0.03          0.02
# 21          1.82              0.03          0.02
# 48          2.04              0.02          0.02
# 22          1.99              0.03          0.02
# 49          2.00              0.03          0.02
# 23          1.95              0.03          0.02
# 50          2.04              0.03          0.02

# %%
training_results_df.loc[training_results_df['threshold']==2].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
training_results_df.loc[training_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
training_results_df.loc[training_results_df['threshold']==4].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
test_path='results/test/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
test_results_df=pd.read_csv('{}backtest_test_2h.csv'.format(test_path),names=header)
#backtest_results_df.columns['chosen_symbol','compare_symbol','timeframe','threshold','takeprofit','stoploss','period','PnL_final']
#test_results_df=test_results_df.loc[test_results_df['threshold']==2]
test_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)
test_results_df.sort_values(by=['threshold','period'],inplace=True)

# %%
test_results_df
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 66      AVAXUSDT       ATOMUSDT        2h          2      20     383.53
# 67      AVAXUSDT       ATOMUSDT        2h          2      21     757.40
# 68      AVAXUSDT       ATOMUSDT        2h          2      22     994.87
# 69      AVAXUSDT       ATOMUSDT        2h          2      23    1385.18
# 70      AVAXUSDT       ATOMUSDT        2h          2      24    2361.59
# ..           ...            ...       ...        ...     ...        ...
# 58      AVAXUSDT       ATOMUSDT        2h          4      52    -477.51
# 59      AVAXUSDT       ATOMUSDT        2h          4      54    -477.04
# 60      AVAXUSDT       ATOMUSDT        2h          4      56    -453.08
# 61      AVAXUSDT       ATOMUSDT        2h          4      58    -123.11
# 62      AVAXUSDT       ATOMUSDT        2h          4      60     -74.26
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 66          0.55              0.80          1.09
# 67          0.83              0.67          0.57
# 68          1.01              0.63          0.40
# 69          1.20              0.63          0.29
# 70          1.58              0.54          0.21
# ..           ...               ...           ...
# 58         -2.09              0.39          0.02
# 59         -2.09              0.39          0.02
# 60         -2.11              0.37          0.02
# 61         -0.38              0.27          0.11
# 62         -0.26              0.17          0.17
#
# [71 rows x 9 columns]

# %%
test_results_df.loc[test_results_df['threshold']==2].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
test_results_df.loc[test_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
test_results_df.loc[test_results_df['threshold']==4].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>
