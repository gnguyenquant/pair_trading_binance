# %%
import pandas as pd

# %%
training_path='results/training/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
training_results_df=pd.read_csv('{}backtest_training_2h.csv'.format(training_path),names=header)
#backtest_results_df.columns['chosen_symbol','compare_symbol','timeframe','threshold','takeprofit','stoploss','period','PnL_final']
training_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)

# %%
training_results_df.sort_values(by=['threshold','period'],inplace=True)
training_results_df
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0        NEARUSDT       ATOMUSDT        2h          2      20    -322.64
# 1        NEARUSDT       ATOMUSDT        2h          2      25     -52.60
# 2        NEARUSDT       ATOMUSDT        2h          2      30     554.03
# 3        NEARUSDT       ATOMUSDT        2h          2      35     -64.84
# 4        NEARUSDT       ATOMUSDT        2h          2      40     727.00
# ..            ...            ...       ...        ...     ...        ...
# 153      NEARUSDT       ATOMUSDT        2h          4      80      31.70
# 47       NEARUSDT       ATOMUSDT        2h          4      85     -79.98
# 48       NEARUSDT       ATOMUSDT        2h          4      90    -441.96
# 49       NEARUSDT       ATOMUSDT        2h          4      95    -400.23
# 50       NEARUSDT       ATOMUSDT        2h          4     100    -169.01
#
#      Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0           -0.37              0.67          0.69
# 1            0.10              0.54          4.37
# 2            0.84              0.38          0.49
# 3            0.02              0.48          3.30
# 4            1.00              0.35          0.32
# ..            ...               ...           ...
# 153         -0.05              0.16          0.37
# 47          -0.60              0.15          0.13
# 48          -1.53              0.34          0.02
# 49          -1.35              0.36          0.03
# 50          -0.62              0.21          0.08
#
# [131 rows x 9 columns]

# %%
training_results_df.loc[training_results_df['threshold']==2]
# Out:
#    chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 0       NEARUSDT       ATOMUSDT        2h          2      20    -322.64
# 1       NEARUSDT       ATOMUSDT        2h          2      25     -52.60
# 2       NEARUSDT       ATOMUSDT        2h          2      30     554.03
# 3       NEARUSDT       ATOMUSDT        2h          2      35     -64.84
# 4       NEARUSDT       ATOMUSDT        2h          2      40     727.00
# 5       NEARUSDT       ATOMUSDT        2h          2      45     432.30
# 51      NEARUSDT       ATOMUSDT        2h          2      50     479.10
# 52      NEARUSDT       ATOMUSDT        2h          2      51     668.56
# 53      NEARUSDT       ATOMUSDT        2h          2      52     785.54
# 54      NEARUSDT       ATOMUSDT        2h          2      53     799.16
# 55      NEARUSDT       ATOMUSDT        2h          2      54    1561.21
# 56      NEARUSDT       ATOMUSDT        2h          2      55     854.65
# 57      NEARUSDT       ATOMUSDT        2h          2      56    1216.65
# 58      NEARUSDT       ATOMUSDT        2h          2      57    1550.42
# 59      NEARUSDT       ATOMUSDT        2h          2      58    2115.73
# 60      NEARUSDT       ATOMUSDT        2h          2      59    1502.49
# 61      NEARUSDT       ATOMUSDT        2h          2      60    1922.03
# 62      NEARUSDT       ATOMUSDT        2h          2      61    1772.90
# 63      NEARUSDT       ATOMUSDT        2h          2      62    1739.18
# 64      NEARUSDT       ATOMUSDT        2h          2      63    1788.95
# 65      NEARUSDT       ATOMUSDT        2h          2      64    2149.77
# 66      NEARUSDT       ATOMUSDT        2h          2      65    2119.45
# 67      NEARUSDT       ATOMUSDT        2h          2      66    1368.66
# 68      NEARUSDT       ATOMUSDT        2h          2      67    1675.28
# 69      NEARUSDT       ATOMUSDT        2h          2      68    1518.24
# 70      NEARUSDT       ATOMUSDT        2h          2      69    1162.36
# 71      NEARUSDT       ATOMUSDT        2h          2      70    1253.79
# 72      NEARUSDT       ATOMUSDT        2h          2      71    1134.73
# 73      NEARUSDT       ATOMUSDT        2h          2      72     518.92
# 74      NEARUSDT       ATOMUSDT        2h          2      73     657.23
# 75      NEARUSDT       ATOMUSDT        2h          2      74     649.24
# 76      NEARUSDT       ATOMUSDT        2h          2      75     842.77
# 77      NEARUSDT       ATOMUSDT        2h          2      76     762.06
# 78      NEARUSDT       ATOMUSDT        2h          2      77    1182.32
# 79      NEARUSDT       ATOMUSDT        2h          2      78    1070.00
# 80      NEARUSDT       ATOMUSDT        2h          2      79     711.44
# 81      NEARUSDT       ATOMUSDT        2h          2      80     498.09
# 31      NEARUSDT       ATOMUSDT        2h          2      85      62.90
# 32      NEARUSDT       ATOMUSDT        2h          2      90     329.13
# 33      NEARUSDT       ATOMUSDT        2h          2      95       8.35
# 34      NEARUSDT       ATOMUSDT        2h          2     100     478.02
#
#     Sharpe ratio  Maximal Drawdown  Fee over PnL
# 0          -0.37              0.67          0.69
# 1           0.10              0.54          4.37
# 2           0.84              0.38          0.49
# 3           0.02              0.48          3.30
# 4           1.00              0.35          0.32
# 5           0.64              0.66          0.54
# 51          0.68              0.59          0.48
# 52          0.79              0.71          0.38
# 53          0.88              0.71          0.32
# 54          0.93              0.58          0.30
# 55          1.26              0.71          0.20
# 56          0.93              0.63          0.30
# 57          1.11              0.70          0.24
# 58          1.23              0.52          0.20
# 59          1.48              0.51          0.15
# 60          1.26              0.48          0.18
# 61          1.44              0.42          0.15
# 62          1.43              0.39          0.15
# 63          1.40              0.41          0.15
# 64          1.39              0.43          0.15
# 65          1.47              0.45          0.14
# 66          1.44              0.47          0.14
# 67          1.20              0.47          0.17
# 68          1.33              0.49          0.16
# 69          1.27              0.45          0.17
# 70          1.08              0.48          0.21
# 71          1.16              0.46          0.19
# 72          1.09              0.49          0.21
# 73          0.72              0.49          0.36
# 74          0.81              0.46          0.29
# 75          0.80              0.51          0.30
# 76          0.94              0.51          0.24
# 77          0.88              0.52          0.26
# 78          1.11              0.59          0.18
# 79          1.03              0.60          0.20
# 80          0.82              0.64          0.28
# 81          0.69              0.57          0.36
# 31          0.33              0.43          2.33
# 32          0.56              0.42          0.49
# 33          0.21              0.44         16.98
# 34          0.67              0.40          0.35

# %%
training_results_df.loc[training_results_df['threshold']==2].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
training_results_df.loc[training_results_df['threshold']==3]
# Out:
#     chosen_symbol compare_symbol timeframe  threshold  period  PnL_final  \
# 9        NEARUSDT       ATOMUSDT        2h          3      20    -103.74
# 10       NEARUSDT       ATOMUSDT        2h          3      25    -351.00
# 11       NEARUSDT       ATOMUSDT        2h          3      30     -78.91
# 12       NEARUSDT       ATOMUSDT        2h          3      35    -411.69
# 13       NEARUSDT       ATOMUSDT        2h          3      40    -685.11
# 14       NEARUSDT       ATOMUSDT        2h          3      45    -405.63
# 15       NEARUSDT       ATOMUSDT        2h          3      50    -340.88
# 16       NEARUSDT       ATOMUSDT        2h          3      55    -444.48
# 82       NEARUSDT       ATOMUSDT        2h          3      60     151.58
# 83       NEARUSDT       ATOMUSDT        2h          3      61    -398.14
# 84       NEARUSDT       ATOMUSDT        2h          3      62    -462.28
# 85       NEARUSDT       ATOMUSDT        2h          3      63    -101.23
# 86       NEARUSDT       ATOMUSDT        2h          3      64     182.96
# 87       NEARUSDT       ATOMUSDT        2h          3      65     378.68
# 88       NEARUSDT       ATOMUSDT        2h          3      66     310.66
# 89       NEARUSDT       ATOMUSDT        2h          3      67     406.38
# 90       NEARUSDT       ATOMUSDT        2h          3      68     467.89
# 91       NEARUSDT       ATOMUSDT        2h          3      69     906.85
# 92       NEARUSDT       ATOMUSDT        2h          3      70     871.83
# 93       NEARUSDT       ATOMUSDT        2h          3      71     755.77
# 94       NEARUSDT       ATOMUSDT        2h          3      72     800.81
# 95       NEARUSDT       ATOMUSDT        2h          3      73    1178.37
# 96       NEARUSDT       ATOMUSDT        2h          3      74    1097.95
# 97       NEARUSDT       ATOMUSDT        2h          3      75    1424.20
# 98       NEARUSDT       ATOMUSDT        2h          3      76    1412.71
# 99       NEARUSDT       ATOMUSDT        2h          3      77    1889.33
# 100      NEARUSDT       ATOMUSDT        2h          3      78    1932.36
# 101      NEARUSDT       ATOMUSDT        2h          3      79    1996.53
# 102      NEARUSDT       ATOMUSDT        2h          3      80    2097.58
# 103      NEARUSDT       ATOMUSDT        2h          3      81    1945.82
# 104      NEARUSDT       ATOMUSDT        2h          3      82    1745.50
# 105      NEARUSDT       ATOMUSDT        2h          3      83    1686.32
# 106      NEARUSDT       ATOMUSDT        2h          3      84    1897.30
# 107      NEARUSDT       ATOMUSDT        2h          3      85    2187.28
# 108      NEARUSDT       ATOMUSDT        2h          3      86    1536.85
# 109      NEARUSDT       ATOMUSDT        2h          3      87    1464.11
# 110      NEARUSDT       ATOMUSDT        2h          3      88    1512.69
# 111      NEARUSDT       ATOMUSDT        2h          3      89    1549.26
# 112      NEARUSDT       ATOMUSDT        2h          3      90    1628.46
# 113      NEARUSDT       ATOMUSDT        2h          3      91    1491.34
# 114      NEARUSDT       ATOMUSDT        2h          3      92    1470.30
# 115      NEARUSDT       ATOMUSDT        2h          3      93    1298.40
# 116      NEARUSDT       ATOMUSDT        2h          3      94    1400.25
# 117      NEARUSDT       ATOMUSDT        2h          3      95     922.95
# 118      NEARUSDT       ATOMUSDT        2h          3      96     949.27
# 119      NEARUSDT       ATOMUSDT        2h          3      97     580.66
# 120      NEARUSDT       ATOMUSDT        2h          3      98     593.43
# 121      NEARUSDT       ATOMUSDT        2h          3      99     614.57
# 122      NEARUSDT       ATOMUSDT        2h          3     100     637.21
#
#      Sharpe ratio  Maximal Drawdown  Fee over PnL
# 9            0.02              0.44          0.94
# 10          -0.34              0.55          0.25
# 11           0.06              0.43          1.09
# 12          -0.60              0.66          0.16
# 13          -1.29              0.81          0.09
# 14          -0.63              0.60          0.16
# 15          -0.45              0.57          0.18
# 16          -0.73              0.56          0.12
# 82           0.36              0.49          0.41
# 83          -0.40              0.48          0.12
# 84          -0.50              0.48          0.10
# 85           0.07              0.46          0.49
# 86           0.41              0.41          0.27
# 87           0.60              0.37          0.14
# 88           0.54              0.37          0.17
# 89           0.63              0.37          0.13
# 90           0.69              0.35          0.12
# 91           1.00              0.42          0.07
# 92           1.02              0.39          0.07
# 93           0.93              0.39          0.08
# 94           0.96              0.40          0.08
# 95           1.20              0.35          0.06
# 96           1.15              0.42          0.06
# 97           1.34              0.41          0.05
# 98           1.34              0.42          0.05
# 99           1.55              0.37          0.04
# 100          1.56              0.39          0.04
# 101          1.59              0.38          0.04
# 102          1.60              0.40          0.04
# 103          1.56              0.39          0.04
# 104          1.45              0.39          0.04
# 105          1.42              0.41          0.04
# 106          1.52              0.39          0.04
# 107          1.54              0.44          0.04
# 108          1.45              0.41          0.05
# 109          1.42              0.40          0.05
# 110          1.45              0.40          0.05
# 111          1.49              0.39          0.05
# 112          1.56              0.38          0.05
# 113          1.36              0.40          0.05
# 114          1.36              0.38          0.05
# 115          1.32              0.37          0.06
# 116          1.37              0.37          0.05
# 117          1.10              0.42          0.08
# 118          1.12              0.42          0.07
# 119          0.94              0.32          0.10
# 120          0.95              0.33          0.09
# 121          0.98              0.33          0.09
# 122          1.01              0.33          0.09

# %%
training_results_df.loc[training_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
training_results_df.loc[training_results_df['threshold']==4].plot(x='period',y='Sharpe ratio')
# Out:
# <AxesSubplot:xlabel='period'>

# %%
test_path='results/test/'
header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
test_results_df=pd.read_csv('{}backtest_test_2h.csv'.format(test_path),names=header)
#backtest_results_df.columns['chosen_symbol','compare_symbol','timeframe','threshold','takeprofit','stoploss','period','PnL_final']
#test_results_df=test_results_df.loc[test_results_df['threshold']==2]
test_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)
test_results_df.sort_values(by=['threshold','period'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/schrodinger/Desktop/work/python/Ongoing_projects/binance_pair_trading/pre_trade/backtest/2h/NEARUSDT_ATOMUSDT/analysis_pairtrading.ipynb Cell 9 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/schrodinger/Desktop/work/python/Ongoing_projects/binance_pair_trading/pre_trade/backtest/2h/NEARUSDT_ATOMUSDT/analysis_pairtrading.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> test_path='results/test/'
#       <a href='vscode-notebook-cell:/home/schrodinger/Desktop/work/python/Ongoing_projects/binance_pair_trading/pre_trade/backtest/2h/NEARUSDT_ATOMUSDT/analysis_pairtrading.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> header=['chosen_symbol','compare_symbol','timeframe','threshold','period','PnL_final','Sharpe ratio','Maximal Drawdown','Fee over PnL']
# ----> <a href='vscode-notebook-cell:/home/schrodinger/Desktop/work/python/Ongoing_projects/binance_pair_trading/pre_trade/backtest/2h/NEARUSDT_ATOMUSDT/analysis_pairtrading.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> test_results_df=pd.read_csv('{}backtest_test_2h.csv'.format(test_path),names=header)
#       <a href='vscode-notebook-cell:/home/schrodinger/Desktop/work/python/Ongoing_projects/binance_pair_trading/pre_trade/backtest/2h/NEARUSDT_ATOMUSDT/analysis_pairtrading.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> #backtest_results_df.columns['chosen_symbol','compare_symbol','timeframe','threshold','takeprofit','stoploss','period','PnL_final']
#       <a href='vscode-notebook-cell:/home/schrodinger/Desktop/work/python/Ongoing_projects/binance_pair_trading/pre_trade/backtest/2h/NEARUSDT_ATOMUSDT/analysis_pairtrading.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> #test_results_df=test_results_df.loc[test_results_df['threshold']==2]
#       <a href='vscode-notebook-cell:/home/schrodinger/Desktop/work/python/Ongoing_projects/binance_pair_trading/pre_trade/backtest/2h/NEARUSDT_ATOMUSDT/analysis_pairtrading.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> test_results_df.drop_duplicates(subset=['threshold','period'],keep='last',inplace=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/test/backtest_test_2h.csv'

# %%
test_results_df

# %%
test_results_df.loc[test_results_df['threshold']==2].plot(x='period',y='Sharpe ratio')

# %%
test_results_df.loc[test_results_df['threshold']==3].plot(x='period',y='Sharpe ratio')

# %%
test_results_df.loc[test_results_df['threshold']==4].plot(x='period',y='Sharpe ratio')
