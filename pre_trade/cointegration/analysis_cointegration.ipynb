# %%
import pandas as pd
from PIL import Image

# %%
data_path='../../data/'
cointegration_path=data_path+'cointegration/'
klines_path=data_path+'klines/'
figures_path=cointegration_path+'figures/'

# %%
layer1_1h_df=pd.read_csv(cointegration_path+'tables/layer1_1h.csv')
layer1_2h_df=pd.read_csv(cointegration_path+'tables/layer1_2h.csv')
layer1_1d_df=pd.read_csv(cointegration_path+'tables/layer1_1d.csv')
layer1_15m_df=pd.read_csv(cointegration_path+'tables/layer1_15m.csv')

# %%
layer1_1h_df
# Out:
#    chosen_symbol compare_symbol  correlation  hedgingratio_slope  \
# 0        DOTUSDT       NEARUSDT     0.981203            0.856262
# 1        ETHUSDT       ALGOUSDT     0.379476            0.426866
# 2        ADAUSDT       ALGOUSDT     0.378985            0.355826
# 3        DOTUSDT       ALGOUSDT     0.949859            0.651149
# 4       AVAXUSDT       ATOMUSDT     0.971806            0.643668
# 5        DOTUSDT       ATOMUSDT     0.960625            0.655787
# 6       AVAXUSDT        DOTUSDT     0.969486            0.913728
# 7       ALGOUSDT       NEARUSDT     0.955808            1.132135
# 8       NEARUSDT       ATOMUSDT     0.958291            0.791857
# 9        BNBUSDT       ALGOUSDT     0.740615            1.197739
# 10      AVAXUSDT       NEARUSDT     0.957459            0.755793
# 11       ETHUSDT        BNBUSDT    -0.069287           -0.068157
#
#     spread_intercept    pvalue
# 0          -1.475167  0.000099
# 1          -3.503513  0.000602
# 2          -0.186192  0.000730
# 3          -2.102196  0.000809
# 4           0.789090  0.001510
# 5           0.621773  0.007489
# 6           0.436107  0.009813
# 7           1.260513  0.012669
# 8           1.717580  0.014341
# 9          -4.784267  0.014382
# 10         -1.021132  0.024333
# 11          2.921537  0.036033

# %%
chosen_symbol='DOTUSDT'
compare_symbol='NEARUSDT'
timeframe='1h'
fig=Image.open('{}{}_{}_{}.png'.format(figures_path,chosen_symbol,compare_symbol,timeframe))
fig.show()

# %%
layer1_2h_df
# Out:
#    chosen_symbol compare_symbol  correlation  hedgingratio_slope  \
# 0        DOTUSDT       NEARUSDT     0.981201            0.855918
# 1        DOTUSDT       ALGOUSDT     0.949858            0.651066
# 2        ADAUSDT       ALGOUSDT     0.378652            0.355641
# 3        ETHUSDT       ALGOUSDT     0.379047            0.426586
# 4       AVAXUSDT       ATOMUSDT     0.971709            0.643273
# 5       NEARUSDT       ATOMUSDT     0.958245            0.791915
# 6        DOTUSDT       ATOMUSDT     0.960630            0.655782
# 7       AVAXUSDT        DOTUSDT     0.969392            0.913180
# 8        BNBUSDT       ALGOUSDT     0.740478            1.197931
# 9       AVAXUSDT       NEARUSDT     0.957250            0.755292
# 10      ALGOUSDT       NEARUSDT     0.955754            1.131829
# 11       ETHUSDT        BNBUSDT    -0.069648           -0.068629
#
#     spread_intercept    pvalue
# 0          -1.473893  0.000063
# 1          -2.102069  0.000167
# 2          -0.186667  0.000818
# 3          -3.501916  0.002370
# 4           0.789791  0.004551
# 5           1.717232  0.004701
# 6           0.621814  0.005321
# 7           0.437011  0.007159
# 8          -4.784654  0.012314
# 9          -1.019775  0.015293
# 10          1.260763  0.016815
# 11          2.923524  0.035532
